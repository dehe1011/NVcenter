# %% [markdown]
# # RL agent for unitary gate building

# %% [markdown]
# We want to try and implement a RL agent (following various algorithms) that learn how to build a target unitary gate in a spin chain with control on the single qubits. The agent builds a parametrized circuit of N layers (with N initially fixed) and with constant structure (but variable parameters).

# %% [markdown]
# See also: https://github.com/ManuelGuatto/RL_4_Robust_QC/blob/main/PPO_Nominal_Damp.ipynb

# %%
import sys
print("Python version:", sys.version)
import torch
# Out:
# Python version: 3.10.11 (v3.10.11:7d4cc5aa85, Apr  4 2023, 19:05:19) [Clang 13.0.0 (clang-1300.0.29.30)]

# %%
from functools import partial
import pennylane as qml
import matplotlib.pyplot as plt
import numpy as np
import timeit
import gymnasium as gym
import stable_baselines3
from gymnasium import spaces
import qutip as q

# %% [markdown]
# ## Define functions:

# %% [markdown]
# Here I use pennylane but all could be accompliched with just numpy. I define layers X rotations, parametrized by the angles, and free evolution times, parametrized by the time. The agent will pile these up in the attempt to find the target gate which in this example is the CNOT gate and the control is on a single qubit.

# %%
num_wires = 2

X, Y, Z = qml.PauliX, qml.PauliY, qml.PauliZ

one = 1/2*(Z(wires= [0]) + qml.Identity(wires=[0]))
two = 1/2*(-Z(wires= [0]) + qml.Identity(wires=[0]))


Id = qml.Identity(wires=[0,1]).matrix()
#param0 = -0.158
#param1 = 0.110
#param2 = -(0.158+0.152)

ops =  [one @ (Z(1))]
ops2 = [two @ ((X(1))) ]
ops3 = [two @ ((Z(1))) ]
#ops3 = [ qml.Identity(wires = 0) @ Z(1)]

couplings = [0.1]
couplings2 = [0.2]
couplings3=[0.01]

H = qml.dot(couplings,ops)+qml.dot(couplings2,ops2)+qml.dot(couplings3,ops3)
#H = ops + ops2
#H0 = qml.dot(couplings2,ops2)
#H1 = qml.dot(couplings3,ops3)

def Ufree(T):
    evo = qml.exp(H, -1j * T)
    return evo.matrix()

def Urot(params):

    ops = qml.Rot(params[0],params[1],wires=0) @ qml.Identity(wires = 1)
    return ops.matrix()

def PulseX(params):

    ops = qml.RX(params,wires=0) @ qml.Identity(wires = 1)
    return ops.matrix()

def PulseY(params):

    ops = qml.RY(params,wires=0) @ qml.Identity(wires = 1)
    return ops.matrix()

# In here, the params[0] is the Rabi frequency times the duration time, i.e. it is directly the rotation angle. The other 2 parameters are the phases
def MWcontrol(params):
    coeff=[params[0]*np.cos(params[1]),params[0]*np.sin(params[1])]
    op = [X(0) @ qml.Identity(1),Y(0) @ qml.Identity(1)]
    Hmw = qml.dot(coeff,op)

    ops = qml.exp(Hmw, -1j)
    return ops.matrix()



#one
#two
#ops3
#q.Qobj(H.matrix())
#MW=q.Qobj(MWcontrol([np.pi/2,np.pi]))
#MW*M
#q.Qobj(H.matrix())

# %%
num_wires = 2

X, Y, Z = qml.PauliX, qml.PauliY, qml.PauliZ

proj_0 = 1/2*(Z(wires= [0]) + qml.Identity(wires=[0]))
proj_1 = 1/2*(-Z(wires= [0]) + qml.Identity(wires=[0]))


Id = qml.Identity(wires=[0,1]).matrix()
#param0 = -0.158
#param1 = 0.110
#param2 = -(0.158+0.152)

ops =  [proj_0 @ (Z(1)/2),proj_1 @ (Z(1)/2),proj_1 @ (X(1)/2)]

couplings = [-2*np.pi*0.158,-2*np.pi*(0.158-0.152),-2*np.pi*0.110]

H = qml.dot(couplings,ops)

def Ufree(T):
    evo = qml.exp(H, -1j * T)
    return evo.matrix()

def UpulseV2(params):
    # parameters are: [time interval duration, phase]
    
    rabi_f = 0.5*2*np.pi
    coeff=[rabi_f*np.cos(params[1]),rabi_f*np.sin(params[1])]

    op = [X(0) @ qml.Identity(1),Y(0) @ qml.Identity(1)]
    Hmw = qml.dot(coeff,op)
    
    Htot = H+Hmw
    
    deltaT = np.abs(params[0])

    evo = qml.exp(Htot, -1j * deltaT)
    
    return evo.matrix()

# %%
def suter_layer(params):
    # Here we can define a layer as an evolution without pulse control follow by a pulse control with fixed Rabi frequency
    U = UpulseV2([params[1],params[2]]) @ Ufree(params[0])
    return U

# %%
def layer(params):
    U = MWcontrol([params[1],params[2]]) @ Ufree(params[0])
    return U


def profit(op_mat,target_mat):
    """Compute the fidelity function for given parameters."""
    #op_mat = param_circ(Nfree,params)
    # Compute the fidelity between the target and the gate
    return np.abs(np.trace(target_mat.conj().T @ ( op_mat))) / 2**num_wires
#np.abs(np.trace(target_mat.conj().T @ op_mat)) / np.abs(np.trace(target_mat.conj().T @ target_mat)) #


#def profit2(op_mat,target_mat,alpha,duration):
    """Compute the fidelity function for given parameters."""
    #op_mat = param_circ(Nfree,params)
    #total_time = 0
    #for i in range(Nfree):
    #    total_time= total_time+params[i]
    # Compute the fidelity between the target and the gate
#    return np.abs(np.trace(target_mat.conj().T @ op_mat)) / 2**num_wires-alpha*duration 

#profit(target2,target2)

# %% [markdown]
# ## Define the environment:

# %% [markdown]
# Here I use a continuos action space of shape (4,), where the first parameter is the time of free evolution while the other thee the Raboi frequency (times pulse duration) and the two phases of teh MW control.
#
#
# The observtaion space could be defined as a dictionary in which to include the real and imaginary part of the gate matrix elemenets as vectors (16,). However, here I concatenate the vectors representing the real and imaginary part in a unique vector (32,). The entries of the observation space are already symmetric and normalized otherwise I would need to normalize them as for best practices. The action space is discrete since it should in principle be easier for the agent to navigate (but can be made continuos using the Box space and normalizing as for best practises).

# %%
class Parametric_env(gym.Env):
    """
    Custom Environment that follows gym interface.
    """

    #metadata = {"render_modes": ["console"]}

    MAX_STEPS = 3
    INFIDELITY_THRESHOLD = 0.001


    def __init__(self, env_conf):
        #super(Parametric_env, self).__init__()
        #self.render_mode = render_mode

        self.target = env_conf["Target"]#qml.Toffoli([0, 1, 2]).matrix()
        self.alpha = env_conf["Lagrange_time"]

        self.U = Id

        #Define the action and observation spaces
        #self.action_space = spaces.Box(low=0, high=np.array([0.02, 
        #                                                     2*np.pi, 2*np.pi, 2*np.pi, 2*np.pi, 
        #                                                     2*np.pi, 2*np.pi, 2*np.pi, 2*np.pi, 
        #                                                     2*np.pi]), dtype=np.float32)
        #Here we normalize the action space
        self.action_space = spaces.Box(low=-1, high= 1, shape=(3,), dtype=np.float32)
        
        #self.action_space = spaces.Dict(
        #    {
        #        "angle_Z": spaces.Discrete(5, start=-2, seed=42),
        #        "angle_X": spaces.Discrete(5, start=-2, seed=42),
        #    }
        #)
        #self.action_space = spaces.MultiDiscrete([5,5],start=[-2,-2])
        #self.action_space = spaces.MultiDiscrete([10,9,9,9])
        self.observation_space = spaces.Box(low=-1, high=1, shape=(32,), dtype=np.float64)

        #self.observation_space = spaces.Dict(
        #    {
        #        "real_part": spaces.Box(low=-1, high=1, shape=(4,), dtype=np.float64),
        #        "imaginary_part": spaces.Box(low=-1, high=1, shape=(4,), dtype=np.float64),
        #    }
        #)

    # Function that gets the state and gives the observation in the correct format
    def _get_obs(self):
        #return {"real_part": np.real(self.U), "imaginary_part": np.imag(self.U)}
        obs = np.concatenate([np.real(self.U.reshape(16,)),np.imag(self.U.reshape(16,))])
        return obs
    #def _get_obs(self):
    #    #return {"real_part": np.real(self.U), "imaginary_part": np.imag(self.U)}
    #    return {"real_part": np.real(self.U.reshape(4,)), "imaginary_part": np.imag(self.U.reshape(4,))}
    
    def reset(self,seed=None, options=None):
        super().reset(seed=seed)
        self.U = Id
        #self.rho_hat = self.rho
        #self.true_fidelity = 0
        self.fidelity = profit(self.U,self.target)#0
        self.count = 0
        self.reward = 0
        self.done = False
        self.duration = 0
        observation = self._get_obs()
        self.info = {}

        return observation,{}
    
    # Function to convert the action sampled from action_space into angles for the rotations in the layer
    def _get_angle(self,para):
        az = np.pi*para
        
        return az
    
    # Function to renormlize the times in between [0,10]
    def _get_times(self,para):
        az = 1*np.abs(para)   #TIMES##########################################
        
        return az
    # Function to renormlize the times in between [0,10]
    def _get_times2(self,para):
        az = 1.6*np.abs(para)   #TIMES##########################################
        
        return az



    def step(self, action):
        #Check the state of the episode
        if self.done:
            print("EPISODE DONE!!!")
        elif (self.count == self.MAX_STEPS):
            self.done = True;
            #truncated = self.done; 
        else:
            assert self.action_space.contains(action)
            self.count += 1
            #self.duration += 4*np.pi*np.abs(action[0])
            
            
        #Define the effect of the unitary layer
        self.params = [self._get_times(action[0]),self._get_times2(action[1]),self._get_angle(action[2])] 
        op = suter_layer(self.params)

        Upre = self.U

        self.U = op @ self.U  ###!
        #print("unitary=", self.U)

        #Compute the reward
        #fid0 = self.fidelity
        #fid = profit(self.U,self.target)
        #fid = profit2(self.U,self.target,self.alpha,self.duration)
        self.fidelity = profit(self.U,self.target)
        
        #if self.done:
        #    self.reward = self.fidelity
        #else:
        #    self.reward = 0
        #self.reward = fid#-fid0#self.fidelity
        self.info = {"Fidelity": self.fidelity,"Pre":Upre,"Next":self.U}

        if 1-self.fidelity < self.INFIDELITY_THRESHOLD:
            self.done = True

        # We give reward only at the end of the episode
        if self.done:
            self.reward =  -np.log(1-self.fidelity) #-0.05*self.count
        else:
            self.reward = 0

        #Rewavrds at each step
        #self.reward = self.fidelity - fid0
        observation = self._get_obs()

        
        #try:
        #    assert self.observation_space.contains(self.rho)
        #except AssertionError:
        #    print("INVALID STATE", self.rho)
        #terminated = self.done
        return [observation, self.reward, self.done,self.done, self.info]

   

        
    def close(self):
        pass

# %% [markdown]
# ## Check the compatibility of the environment with stable baseline 3:

# %%
from stable_baselines3.common.env_checker import check_env

# %%
rho_target = Id
alpha = 1

# %%
env = Parametric_env(env_conf={"Target": rho_target,"Lagrange_time":alpha})
# If the environment don't follow the interface, an error will be thrown
check_env(env, warn=True)

# %% [markdown]
# ## Define target, instanciate the environment, and train a chosen model:

# %%
target = qml.CNOT(wires=[0,1]).matrix()
target2 = (qml.Identity(0) @ qml.Hadamard(wires=[1])).matrix()
alpha = 0
target_gate = target2
target_gate
#qml.RX(params,wires=0) @ qml.Identity(wires = 1) qml.Identity(0).matrix() @
# Out:
# array([[ 0.70710678,  0.70710678,  0.        ,  0.        ],
#        [ 0.70710678, -0.70710678,  0.        , -0.        ],
#        [ 0.        ,  0.        ,  0.70710678,  0.70710678],
#        [ 0.        , -0.        ,  0.70710678, -0.70710678]])

# %%
from stable_baselines3 import PPO, A2C, DQN, TD3, DDPG
from stable_baselines3.common.env_util import make_vec_env

# Instantiate the env
#env_conf=dict(Target=Id,Lagrange_time=alpha)

vec_env = make_vec_env(lambda:Parametric_env(env_conf={"Target": target_gate,"Lagrange_time":alpha})
, n_envs=1)

#vec_env = make_vec_env(Parametric_env, n_envs=1, env_kwargs=dict(Target=Id,Lagrange_time=alpha))

# %%
# %%time

env = Parametric_env(env_conf={"Target": target_gate,"Lagrange_time":alpha})

#policy, env, 
#learning_rate=0.0003, 
#n_steps=2048, 
#batch_size=64, 
#n_epochs=10, 
#gamma=0.99, 
#gae_lambda=0.95, 
#clip_range=0.2, 
#clip_range_vf=None, 
#normalize_advantage=True, 
#ent_coef=0.0, 
#vf_coef=0.5, 
#max_grad_norm=0.5, 
#use_sde=False, 
#sde_sample_freq=-1, 
#rollout_buffer_class=None, 
#rollout_buffer_kwargs=None, 
#target_kl=None, 
#stats_window_size=100, 
#tensorboard_log=None, 
#policy_kwargs=None, 
#verbose=0, 
#seed=None, 
#device='auto',
#_init_setup_model=True)

# Best so far: model = PPO("MlpPolicy", env, gamma=0.9998,n_steps=1024,batch_size=64,clip_range=0.1, n_epochs=10,ent_coef=0.00, verbose=1).learn(4000_000)
# with parameters: t = 7# number = 5

# Train the agent
#MlpPolicy
model = PPO("MlpPolicy", env, learning_rate=0.00005,gamma=0.9996,n_steps=2048,batch_size=256,clip_range=0.2, n_epochs=10,ent_coef=0.001, verbose=1,tensorboard_log="./ppo_cartpole_tensorboard/").learn(4000_000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./ppo_cartpole_tensorboard/PPO_30
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3        |
# |    ep_rew_mean     | 0.528    |
# | time/              |          |
# |    fps             | 1429     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3             |
# |    ep_rew_mean          | 0.676         |
# | time/                   |               |
# |    fps                  | 1368          |
# |    iterations           | 2             |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00027953924 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.26         |
# |    explained_variance   | -0.429        |
# |    learning_rate        | 5e-05         |
# |    loss                 | 0.252         |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.00119      |
# |    std                  | 1             |
# |    value_loss           | 0.573         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 0.641        |
# | time/                   |              |
# |    fps                  | 1345         |
# |    iterations           | 3            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0008033721 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -0.327       |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.163        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00156     |
# |    std                  | 1            |
# |    value_loss           | 0.434        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3             |
# |    ep_rew_mean          | 0.439         |
# | time/                   |               |
# |    fps                  | 1347          |
# |    iterations           | 4             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00023710253 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.26         |
# |    explained_variance   | -0.193        |
# |    learning_rate        | 5e-05         |
# |    loss                 | 0.17          |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.000894     |
# |    std                  | 1             |
# |    value_loss           | 0.381         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 0.598        |
# | time/                   |              |
# |    fps                  | 1341         |
# |    iterations           | 5            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0005426158 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -0.172       |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.124        |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00103     |
# |    std                  | 1            |
# |    value_loss           | 0.315        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 0.618        |
# | time/                   |              |
# |    fps                  | 1341         |
# |    iterations           | 6            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0014613038 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -0.104       |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.159        |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0023      |
# |    std                  | 1            |
# |    value_loss           | 0.332        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 0.624        |
# | time/                   |              |
# |    fps                  | 1336         |
# |    iterations           | 7            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0012631685 |
# |    clip_fraction        | 0.000342     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.27        |
# |    explained_variance   | -0.087       |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.121        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00207     |
# |    std                  | 1            |
# |    value_loss           | 0.288        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 0.596        |
# | time/                   |              |
# |    fps                  | 1336         |
# |    iterations           | 8            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0017339623 |
# |    clip_fraction        | 0.00107      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -0.0544      |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.129        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00265     |
# |    std                  | 1            |
# |    value_loss           | 0.295        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3             |
# |    ep_rew_mean          | 0.569         |
# | time/                   |               |
# |    fps                  | 1334          |
# |    iterations           | 9             |
# |    time_elapsed         | 13            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.00032159156 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.26         |
# |    explained_variance   | -0.0315       |
# |    learning_rate        | 5e-05         |
# |    loss                 | 0.105         |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000894     |
# |    std                  | 1             |
# |    value_loss           | 0.237         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 0.712        |
# | time/                   |              |
# |    fps                  | 1334         |
# |    iterations           | 10           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0012257383 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.27        |
# |    explained_variance   | -0.0156      |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.0953       |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0022      |
# |    std                  | 1            |
# |    value_loss           | 0.252        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 0.626       |
# | time/                   |             |
# |    fps                  | 1334        |
# |    iterations           | 11          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.001386273 |
# |    clip_fraction        | 0.000342    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | -0.0104     |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.109       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00186    |
# |    std                  | 1           |
# |    value_loss           | 0.247       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 0.676        |
# | time/                   |              |
# |    fps                  | 1334         |
# |    iterations           | 12           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0010076995 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.27        |
# |    explained_variance   | -0.0159      |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.141        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0017      |
# |    std                  | 1            |
# |    value_loss           | 0.256        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3             |
# |    ep_rew_mean          | 0.608         |
# | time/                   |               |
# |    fps                  | 1334          |
# |    iterations           | 13            |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00075818674 |
# |    clip_fraction        | 9.77e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.27         |
# |    explained_variance   | -0.00972      |
# |    learning_rate        | 5e-05         |
# |    loss                 | 0.135         |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.0016       |
# |    std                  | 1             |
# |    value_loss           | 0.265         |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 0.819       |
# | time/                   |             |
# |    fps                  | 1334        |
# |    iterations           | 14          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.001122496 |
# |    clip_fraction        | 4.88e-05    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | -0.00467    |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.085       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00184    |
# |    std                  | 1           |
# |    value_loss           | 0.218       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 0.571       |
# | time/                   |             |
# |    fps                  | 1333        |
# |    iterations           | 15          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.001828962 |
# |    clip_fraction        | 0.00151     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | -0.00305    |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.132       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00218    |
# |    std                  | 1           |
# |    value_loss           | 0.283       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 0.612        |
# | time/                   |              |
# |    fps                  | 1331         |
# |    iterations           | 16           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0016266347 |
# |    clip_fraction        | 0.000586     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.27        |
# |    explained_variance   | -0.00606     |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.123        |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00233     |
# |    std                  | 1            |
# |    value_loss           | 0.267        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 0.615        |
# | time/                   |              |
# |    fps                  | 1306         |
# |    iterations           | 17           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0031781732 |
# |    clip_fraction        | 0.00625      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.27        |
# |    explained_variance   | 0.00199      |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.111        |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00378     |
# |    std                  | 1            |
# |    value_loss           | 0.235        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 0.684       |
# | time/                   |             |
# |    fps                  | 1290        |
# |    iterations           | 18          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.002775487 |
# |    clip_fraction        | 0.00288     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.0147      |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.134       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00253    |
# |    std                  | 1           |
# |    value_loss           | 0.273       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 0.664        |
# | time/                   |              |
# |    fps                  | 1263         |
# |    iterations           | 19           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0027551206 |
# |    clip_fraction        | 0.00381      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -0.00959     |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.137        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00306     |
# |    std                  | 1            |
# |    value_loss           | 0.239        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 0.582        |
# | time/                   |              |
# |    fps                  | 1265         |
# |    iterations           | 20           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0063071838 |
# |    clip_fraction        | 0.027        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -0.00419     |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.132        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00622     |
# |    std                  | 1            |
# |    value_loss           | 0.255        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 0.527       |
# | time/                   |             |
# |    fps                  | 1268        |
# |    iterations           | 21          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.004118145 |
# |    clip_fraction        | 0.00894     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.00621     |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.119       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00318    |
# |    std                  | 1           |
# |    value_loss           | 0.264       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 0.681        |
# | time/                   |              |
# |    fps                  | 1271         |
# |    iterations           | 22           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0045060553 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | 0.00635      |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.118        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00382     |
# |    std                  | 1            |
# |    value_loss           | 0.255        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 0.699        |
# | time/                   |              |
# |    fps                  | 1266         |
# |    iterations           | 23           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0038777126 |
# |    clip_fraction        | 0.0116       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | 0.00507      |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.109        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00325     |
# |    std                  | 1            |
# |    value_loss           | 0.259        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 0.612        |
# | time/                   |              |
# |    fps                  | 1266         |
# |    iterations           | 24           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0077095167 |
# |    clip_fraction        | 0.0523       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | 0.00824      |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.141        |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00833     |
# |    std                  | 1            |
# |    value_loss           | 0.306        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 0.749        |
# | time/                   |              |
# |    fps                  | 1239         |
# |    iterations           | 25           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0066183736 |
# |    clip_fraction        | 0.0325       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.00993      |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.107        |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00527     |
# |    std                  | 0.999        |
# |    value_loss           | 0.261        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 0.856       |
# | time/                   |             |
# |    fps                  | 1228        |
# |    iterations           | 26          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.008311382 |
# |    clip_fraction        | 0.0648      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.0118      |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.141       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.998       |
# |    value_loss           | 0.323       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 0.722       |
# | time/                   |             |
# |    fps                  | 1224        |
# |    iterations           | 27          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.007481983 |
# |    clip_fraction        | 0.0617      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.00906     |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.118       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00964    |
# |    std                  | 0.997       |
# |    value_loss           | 0.324       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 0.772       |
# | time/                   |             |
# |    fps                  | 1216        |
# |    iterations           | 28          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.008731354 |
# |    clip_fraction        | 0.0788      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.0118      |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.143       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0108     |
# |    std                  | 0.995       |
# |    value_loss           | 0.344       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 0.83        |
# | time/                   |             |
# |    fps                  | 1216        |
# |    iterations           | 29          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008901145 |
# |    clip_fraction        | 0.0743      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.00905     |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.188       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 0.994       |
# |    value_loss           | 0.402       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 0.789        |
# | time/                   |              |
# |    fps                  | 1220         |
# |    iterations           | 30           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0067627863 |
# |    clip_fraction        | 0.0484       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.24        |
# |    explained_variance   | 0.0146       |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.177        |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00646     |
# |    std                  | 0.993        |
# |    value_loss           | 0.355        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 0.838        |
# | time/                   |              |
# |    fps                  | 1223         |
# |    iterations           | 31           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0071803187 |
# |    clip_fraction        | 0.0519       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.23        |
# |    explained_variance   | 0.0222       |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.186        |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00633     |
# |    std                  | 0.991        |
# |    value_loss           | 0.401        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 0.798        |
# | time/                   |              |
# |    fps                  | 1224         |
# |    iterations           | 32           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0063976985 |
# |    clip_fraction        | 0.0378       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.23        |
# |    explained_variance   | 0.0178       |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.142        |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00564     |
# |    std                  | 0.989        |
# |    value_loss           | 0.376        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 0.896       |
# | time/                   |             |
# |    fps                  | 1224        |
# |    iterations           | 33          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.006518417 |
# |    clip_fraction        | 0.0504      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 0.0171      |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.196       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00725    |
# |    std                  | 0.987       |
# |    value_loss           | 0.418       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 0.846        |
# | time/                   |              |
# |    fps                  | 1227         |
# |    iterations           | 34           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0056128614 |
# |    clip_fraction        | 0.0306       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.21        |
# |    explained_variance   | 0.0144       |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.163        |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00506     |
# |    std                  | 0.986        |
# |    value_loss           | 0.414        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 0.887        |
# | time/                   |              |
# |    fps                  | 1228         |
# |    iterations           | 35           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0058552613 |
# |    clip_fraction        | 0.0475       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.21        |
# |    explained_variance   | 0.0225       |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.183        |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0068      |
# |    std                  | 0.984        |
# |    value_loss           | 0.386        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 0.965        |
# | time/                   |              |
# |    fps                  | 1229         |
# |    iterations           | 36           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0057968264 |
# |    clip_fraction        | 0.0337       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.2         |
# |    explained_variance   | 0.0124       |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.181        |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00461     |
# |    std                  | 0.982        |
# |    value_loss           | 0.408        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 1.02        |
# | time/                   |             |
# |    fps                  | 1230        |
# |    iterations           | 37          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.004189612 |
# |    clip_fraction        | 0.0197      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | 0.0156      |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.174       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00413    |
# |    std                  | 0.98        |
# |    value_loss           | 0.431       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 0.948       |
# | time/                   |             |
# |    fps                  | 1231        |
# |    iterations           | 38          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.004338317 |
# |    clip_fraction        | 0.00762     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.19       |
# |    explained_variance   | 0.0229      |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.223       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00283    |
# |    std                  | 0.977       |
# |    value_loss           | 0.449       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 1.07        |
# | time/                   |             |
# |    fps                  | 1232        |
# |    iterations           | 39          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.005223966 |
# |    clip_fraction        | 0.0452      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.0192      |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.194       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00712    |
# |    std                  | 0.975       |
# |    value_loss           | 0.37        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 1.09        |
# | time/                   |             |
# |    fps                  | 1235        |
# |    iterations           | 40          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.005411079 |
# |    clip_fraction        | 0.0263      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.0197      |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.232       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00403    |
# |    std                  | 0.972       |
# |    value_loss           | 0.431       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 0.951        |
# | time/                   |              |
# |    fps                  | 1238         |
# |    iterations           | 41           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0045167375 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.17        |
# |    explained_variance   | 0.0138       |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.221        |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00297     |
# |    std                  | 0.97         |
# |    value_loss           | 0.488        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 0.991       |
# | time/                   |             |
# |    fps                  | 1236        |
# |    iterations           | 42          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.003815531 |
# |    clip_fraction        | 0.0114      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.0158      |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.19        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00278    |
# |    std                  | 0.968       |
# |    value_loss           | 0.395       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 1.07         |
# | time/                   |              |
# |    fps                  | 1234         |
# |    iterations           | 43           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0059137084 |
# |    clip_fraction        | 0.0297       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.15        |
# |    explained_variance   | 0.0126       |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.196        |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00474     |
# |    std                  | 0.966        |
# |    value_loss           | 0.417        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 0.979        |
# | time/                   |              |
# |    fps                  | 1234         |
# |    iterations           | 44           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0057437224 |
# |    clip_fraction        | 0.037        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.15        |
# |    explained_variance   | 0.0171       |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.182        |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00511     |
# |    std                  | 0.964        |
# |    value_loss           | 0.431        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 1.03        |
# | time/                   |             |
# |    fps                  | 1234        |
# |    iterations           | 45          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.004473252 |
# |    clip_fraction        | 0.02        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.0312      |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.173       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00313    |
# |    std                  | 0.963       |
# |    value_loss           | 0.384       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3          |
# |    ep_rew_mean          | 1.13       |
# | time/                   |            |
# |    fps                  | 1235       |
# |    iterations           | 46         |
# |    time_elapsed         | 76         |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.00780495 |
# |    clip_fraction        | 0.0631     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.14      |
# |    explained_variance   | 0.0341     |
# |    learning_rate        | 5e-05      |
# |    loss                 | 0.204      |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.00815   |
# |    std                  | 0.961      |
# |    value_loss           | 0.406      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 0.966        |
# | time/                   |              |
# |    fps                  | 1235         |
# |    iterations           | 47           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0047559645 |
# |    clip_fraction        | 0.0239       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.13        |
# |    explained_variance   | 0.0253       |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.184        |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00352     |
# |    std                  | 0.959        |
# |    value_loss           | 0.405        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 1.11         |
# | time/                   |              |
# |    fps                  | 1236         |
# |    iterations           | 48           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0063610557 |
# |    clip_fraction        | 0.0516       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.13        |
# |    explained_variance   | 0.0334       |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.16         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00591     |
# |    std                  | 0.957        |
# |    value_loss           | 0.379        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 1.14        |
# | time/                   |             |
# |    fps                  | 1238        |
# |    iterations           | 49          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.005712496 |
# |    clip_fraction        | 0.0214      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.12       |
# |    explained_variance   | 0.0237      |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.156       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00399    |
# |    std                  | 0.955       |
# |    value_loss           | 0.338       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 1.14        |
# | time/                   |             |
# |    fps                  | 1239        |
# |    iterations           | 50          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.004944321 |
# |    clip_fraction        | 0.0128      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.11       |
# |    explained_variance   | 0.0303      |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.175       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0035     |
# |    std                  | 0.952       |
# |    value_loss           | 0.383       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 1.03         |
# | time/                   |              |
# |    fps                  | 1241         |
# |    iterations           | 51           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0059841387 |
# |    clip_fraction        | 0.0247       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.1         |
# |    explained_variance   | 0.0326       |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.154        |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00387     |
# |    std                  | 0.95         |
# |    value_loss           | 0.331        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 1.18        |
# | time/                   |             |
# |    fps                  | 1242        |
# |    iterations           | 52          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.004812641 |
# |    clip_fraction        | 0.0244      |
# |    clip_range           | 0.2         |
# ...
# |    policy_gradient_loss | 0.0152      |
# |    std                  | 0.578       |
# |    value_loss           | 4.93e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 1.8         |
# | time/                   |             |
# |    fps                  | 1282        |
# |    iterations           | 1938        |
# |    time_elapsed         | 3094        |
# |    total_timesteps      | 3969024     |
# | train/                  |             |
# |    approx_kl            | 0.008680321 |
# |    clip_fraction        | 0.0896      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.38        |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0321      |
# |    n_updates            | 19370       |
# |    policy_gradient_loss | 0.00789     |
# |    std                  | 0.577       |
# |    value_loss           | 4.56e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 1.8         |
# | time/                   |             |
# |    fps                  | 1282        |
# |    iterations           | 1939        |
# |    time_elapsed         | 3095        |
# |    total_timesteps      | 3971072     |
# | train/                  |             |
# |    approx_kl            | 0.025211338 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.39        |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0206      |
# |    n_updates            | 19380       |
# |    policy_gradient_loss | 0.0138      |
# |    std                  | 0.578       |
# |    value_loss           | 4.18e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 1.8         |
# | time/                   |             |
# |    fps                  | 1282        |
# |    iterations           | 1940        |
# |    time_elapsed         | 3097        |
# |    total_timesteps      | 3973120     |
# | train/                  |             |
# |    approx_kl            | 0.014762585 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.39        |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.00224     |
# |    n_updates            | 19390       |
# |    policy_gradient_loss | 0.0287      |
# |    std                  | 0.578       |
# |    value_loss           | 4.51e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 1.8         |
# | time/                   |             |
# |    fps                  | 1282        |
# |    iterations           | 1941        |
# |    time_elapsed         | 3098        |
# |    total_timesteps      | 3975168     |
# | train/                  |             |
# |    approx_kl            | 0.006091308 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.39        |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.00498    |
# |    n_updates            | 19400       |
# |    policy_gradient_loss | 0.0154      |
# |    std                  | 0.578       |
# |    value_loss           | 4.07e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 1.8         |
# | time/                   |             |
# |    fps                  | 1282        |
# |    iterations           | 1942        |
# |    time_elapsed         | 3100        |
# |    total_timesteps      | 3977216     |
# | train/                  |             |
# |    approx_kl            | 0.032385238 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.39        |
# |    explained_variance   | 0.892       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0253      |
# |    n_updates            | 19410       |
# |    policy_gradient_loss | 0.0109      |
# |    std                  | 0.577       |
# |    value_loss           | 4.55e-08    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 1.8          |
# | time/                   |              |
# |    fps                  | 1282         |
# |    iterations           | 1943         |
# |    time_elapsed         | 3101         |
# |    total_timesteps      | 3979264      |
# | train/                  |              |
# |    approx_kl            | 0.0047346028 |
# |    clip_fraction        | 0.172        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.39         |
# |    explained_variance   | 0.89         |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.00591      |
# |    n_updates            | 19420        |
# |    policy_gradient_loss | 0.00744      |
# |    std                  | 0.577        |
# |    value_loss           | 4.51e-08     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 1.8         |
# | time/                   |             |
# |    fps                  | 1282        |
# |    iterations           | 1944        |
# |    time_elapsed         | 3103        |
# |    total_timesteps      | 3981312     |
# | train/                  |             |
# |    approx_kl            | 0.019858195 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.4         |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0102      |
# |    n_updates            | 19430       |
# |    policy_gradient_loss | 0.0158      |
# |    std                  | 0.577       |
# |    value_loss           | 4.48e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 1.8         |
# | time/                   |             |
# |    fps                  | 1282        |
# |    iterations           | 1945        |
# |    time_elapsed         | 3104        |
# |    total_timesteps      | 3983360     |
# | train/                  |             |
# |    approx_kl            | 0.009230245 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.4         |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0274      |
# |    n_updates            | 19440       |
# |    policy_gradient_loss | 0.00707     |
# |    std                  | 0.577       |
# |    value_loss           | 4.18e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 1.8         |
# | time/                   |             |
# |    fps                  | 1282        |
# |    iterations           | 1946        |
# |    time_elapsed         | 3106        |
# |    total_timesteps      | 3985408     |
# | train/                  |             |
# |    approx_kl            | 0.006363447 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.4         |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0265      |
# |    n_updates            | 19450       |
# |    policy_gradient_loss | 0.0286      |
# |    std                  | 0.577       |
# |    value_loss           | 4.04e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 1.8         |
# | time/                   |             |
# |    fps                  | 1282        |
# |    iterations           | 1947        |
# |    time_elapsed         | 3107        |
# |    total_timesteps      | 3987456     |
# | train/                  |             |
# |    approx_kl            | 0.026977219 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.4         |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0148     |
# |    n_updates            | 19460       |
# |    policy_gradient_loss | -1.1e-05    |
# |    std                  | 0.577       |
# |    value_loss           | 4.48e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 1.8         |
# | time/                   |             |
# |    fps                  | 1283        |
# |    iterations           | 1948        |
# |    time_elapsed         | 3109        |
# |    total_timesteps      | 3989504     |
# | train/                  |             |
# |    approx_kl            | 0.015284231 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.4         |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0274      |
# |    n_updates            | 19470       |
# |    policy_gradient_loss | 0.0182      |
# |    std                  | 0.578       |
# |    value_loss           | 4.24e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 1.8         |
# | time/                   |             |
# |    fps                  | 1283        |
# |    iterations           | 1949        |
# |    time_elapsed         | 3111        |
# |    total_timesteps      | 3991552     |
# | train/                  |             |
# |    approx_kl            | 0.038750775 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.4         |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0373      |
# |    n_updates            | 19480       |
# |    policy_gradient_loss | 0.0231      |
# |    std                  | 0.578       |
# |    value_loss           | 4.42e-08    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3          |
# |    ep_rew_mean          | 1.8        |
# | time/                   |            |
# |    fps                  | 1283       |
# |    iterations           | 1950       |
# |    time_elapsed         | 3112       |
# |    total_timesteps      | 3993600    |
# | train/                  |            |
# |    approx_kl            | 0.01818836 |
# |    clip_fraction        | 0.113      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.4        |
# |    explained_variance   | 0.894      |
# |    learning_rate        | 5e-05      |
# |    loss                 | -0.0049    |
# |    n_updates            | 19490      |
# |    policy_gradient_loss | 3.35e-05   |
# |    std                  | 0.578      |
# |    value_loss           | 4.39e-08   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 1.8         |
# | time/                   |             |
# |    fps                  | 1283        |
# |    iterations           | 1951        |
# |    time_elapsed         | 3114        |
# |    total_timesteps      | 3995648     |
# | train/                  |             |
# |    approx_kl            | 0.011780159 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.41        |
# |    explained_variance   | 0.888       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0324      |
# |    n_updates            | 19500       |
# |    policy_gradient_loss | 0.00522     |
# |    std                  | 0.578       |
# |    value_loss           | 4.64e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 1.8         |
# | time/                   |             |
# |    fps                  | 1283        |
# |    iterations           | 1952        |
# |    time_elapsed         | 3115        |
# |    total_timesteps      | 3997696     |
# | train/                  |             |
# |    approx_kl            | 0.030184478 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.41        |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0303      |
# |    n_updates            | 19510       |
# |    policy_gradient_loss | 0.0226      |
# |    std                  | 0.578       |
# |    value_loss           | 4.13e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 1.8         |
# | time/                   |             |
# |    fps                  | 1283        |
# |    iterations           | 1953        |
# |    time_elapsed         | 3117        |
# |    total_timesteps      | 3999744     |
# | train/                  |             |
# |    approx_kl            | 0.025307136 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.41        |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0203     |
# |    n_updates            | 19520       |
# |    policy_gradient_loss | 0.00137     |
# |    std                  | 0.577       |
# |    value_loss           | 4.54e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 1.8         |
# | time/                   |             |
# |    fps                  | 1283        |
# |    iterations           | 1954        |
# |    time_elapsed         | 3118        |
# |    total_timesteps      | 4001792     |
# | train/                  |             |
# |    approx_kl            | 0.010400445 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.41        |
# |    explained_variance   | 0.892       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.00345    |
# |    n_updates            | 19530       |
# |    policy_gradient_loss | -0.00388    |
# |    std                  | 0.577       |
# |    value_loss           | 4.47e-08    |
# -----------------------------------------
# CPU times: user 3h 42min 4s, sys: 16min 25s, total: 3h 58min 29s
# Wall time: 51min 58s

# %% [markdown]
# ## Test the trained model:

# %%
# Test the trained agent
# using the vecenv
obs = vec_env.reset()
n_steps = 8
for step in range(n_steps):
    action, _ = model.predict(obs, deterministic= False)
    print(f"Step {step + 1}")
    print("Action: ", [action[0][i] for i in range(3)])
    obs, reward, done, info = vec_env.step(action)
    #print("obs=", obs, "reward=", reward, "done=", done)
    print("reward=", reward,"fidelity=",info[0]["Fidelity"], "done=", done)
    #vec_env.render()
    if done:
        # Note that the VecEnv resets automatically
        # when a done signal is encountered
        if reward > 0.99:
            print("Goal reached", "Fidelity=", info[0])
        else:
            print(" Max number of layers", "Fidelity=", info)
        break
# Out:
# Step 1
# Action:  [0.0045866724, 0.11103537, 1.0]
# reward= [0.] fidelity= 0.04699464632712025 done= [False]
# Step 2
# Action:  [-0.009253545, 1.0, 1.0]
# reward= [0.] fidelity= 0.400783813301019 done= [False]
# Step 3
# Action:  [0.102987215, -1.0, 1.0]
# reward= [0.] fidelity= 0.2822786015887279 done= [False]
# Step 4
# Action:  [0.056610852, -1.0, -1.0]
# reward= [3.7939458] fidelity= 0.9774933790758147 done= [ True]
# Goal reached Fidelity= {'Fidelity': 0.9774933790758147, 'Pre': array([[-0.13447503-0.25659702j, -0.00260434-0.15362235j,
#          0.68060557-0.45129769j,  0.47436824-0.0234318j ],
#        [ 0.00260434-0.15362235j, -0.13447503+0.25659702j,
#          0.47436824+0.0234318j , -0.68060557-0.45129769j],
#        [ 0.70271447-0.44047433j,  0.45176267+0.02351732j,
#         -0.17485094-0.22247576j,  0.00206872-0.16570933j],
#        [ 0.45176267-0.02351732j, -0.70271447-0.44047433j,
#         -0.00206872-0.16570933j, -0.17485094+0.22247576j]]), 'Next': array([[ 0.01889487-0.8228448j , -0.01086648-0.56280273j,
#         -0.00540654-0.00643202j,  0.01503637-0.07353726j],
#        [ 0.01086648-0.56280273j,  0.01889487+0.8228448j ,
#          0.01503637+0.07353726j,  0.00540654-0.00643202j],
#        [ 0.01170758+0.00518092j, -0.0109025 +0.07363185j,
#          0.02129392-0.83577766j,  0.00977675-0.5433436j ],
#        [-0.0109025 -0.07363185j, -0.01170758+0.00518092j,
#         -0.00977675-0.5433436j ,  0.02129392+0.83577766j]]), 'episode': {'r': 3.793946, 'l': 4, 't': 33598.1768}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.01889487, -0.01086648, -0.00540654,  0.01503637,  0.01086648,
#         0.01889487,  0.01503637,  0.00540654,  0.01170758, -0.0109025 ,
#         0.02129392,  0.00977675, -0.0109025 , -0.01170758, -0.00977675,
#         0.02129392, -0.8228448 , -0.56280273, -0.00643202, -0.07353726,
#        -0.56280273,  0.8228448 ,  0.07353726, -0.00643202,  0.00518092,
#         0.07363185, -0.83577766, -0.5433436 , -0.07363185,  0.00518092,
#        -0.5433436 ,  0.83577766])}

# %%
# !tensorboard --logdir ./ppo_cartpole_tensorboard/
# Out:
# TensorFlow installation not found - running with reduced feature set.
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.17.1 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C
